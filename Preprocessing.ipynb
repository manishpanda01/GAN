# %%
import os
import nibabel as nib
import imageio
import numpy as np
import re

# Define your paths
# input_folder = 'path_to_your_nii_files'
# output_folder = 'path_to_output_folders'

# Create output folders if they don't exist
classes = ['AD', 'CN', 'EMCI', 'LMCI', 'MCI']
for cls in classes:
    os.makedirs(os.path.join(output_folder, cls), exist_ok=True)

# Function to convert nii to png or jpeg
def nii_to_image(nii_file, output_file):
    img = nib.load(nii_file)
    img_data = img.get_fdata()
    # Extract the middle slice of the 3D image data
    middle_slice = img_data[:, :, img_data.shape[2] // 2]
    # Normalize the data to the range [0, 255] for saving as an image
    middle_slice = (255 * (middle_slice - np.min(middle_slice)) / (np.max(middle_slice) - np.min(middle_slice))).astype(np.uint8)
    imageio.imwrite(output_file, middle_slice)

# Regular expression pattern to match filenames like MNI_AD1.nii, MNI_CN89.nii, etc.
pattern = re.compile(r'MNI_(AD|CN|EMCI|LMCI|MCI)\d+\.nii')

# Process each nii file
for filename in os.listdir(input_folder):
    if pattern.match(filename):
        file_path = os.path.join(input_folder, filename)
        class_name = re.search(r'MNI_(AD|CN|EMCI|LMCI|MCI)', filename).group(1)
        output_file = os.path.join(output_folder, class_name, filename.replace('.nii', '.png'))
        nii_to_image(file_path, output_file)
        print(f'Converted {filename} to {output_file}')

print("Conversion completed.")
# Out:
# Converted MNI_AD1.nii to ./Original_images\AD\MNI_AD1.png
# Converted MNI_AD10.nii to ./Original_images\AD\MNI_AD10.png
# Converted MNI_AD11.nii to ./Original_images\AD\MNI_AD11.png
# Converted MNI_AD12.nii to ./Original_images\AD\MNI_AD12.png
# Converted MNI_AD13.nii to ./Original_images\AD\MNI_AD13.png
# Converted MNI_AD14.nii to ./Original_images\AD\MNI_AD14.png
# Converted MNI_AD15.nii to ./Original_images\AD\MNI_AD15.png
# Converted MNI_AD16.nii to ./Original_images\AD\MNI_AD16.png
# Converted MNI_AD17.nii to ./Original_images\AD\MNI_AD17.png
# Converted MNI_AD18.nii to ./Original_images\AD\MNI_AD18.png
# Converted MNI_AD19.nii to ./Original_images\AD\MNI_AD19.png
# Converted MNI_AD2.nii to ./Original_images\AD\MNI_AD2.png
# Converted MNI_AD20.nii to ./Original_images\AD\MNI_AD20.png
# Converted MNI_AD21.nii to ./Original_images\AD\MNI_AD21.png
# Converted MNI_AD22.nii to ./Original_images\AD\MNI_AD22.png
# Converted MNI_AD23.nii to ./Original_images\AD\MNI_AD23.png
# Converted MNI_AD24.nii to ./Original_images\AD\MNI_AD24.png
# Converted MNI_AD25.nii to ./Original_images\AD\MNI_AD25.png
# Converted MNI_AD26.nii to ./Original_images\AD\MNI_AD26.png
# Converted MNI_AD27.nii to ./Original_images\AD\MNI_AD27.png
# Converted MNI_AD28.nii to ./Original_images\AD\MNI_AD28.png
# Converted MNI_AD29.nii to ./Original_images\AD\MNI_AD29.png
# Converted MNI_AD3.nii to ./Original_images\AD\MNI_AD3.png
# Converted MNI_AD30.nii to ./Original_images\AD\MNI_AD30.png
# Converted MNI_AD31.nii to ./Original_images\AD\MNI_AD31.png
# Converted MNI_AD32.nii to ./Original_images\AD\MNI_AD32.png
# Converted MNI_AD33.nii to ./Original_images\AD\MNI_AD33.png
# Converted MNI_AD34.nii to ./Original_images\AD\MNI_AD34.png
# Converted MNI_AD35.nii to ./Original_images\AD\MNI_AD35.png
# Converted MNI_AD36.nii to ./Original_images\AD\MNI_AD36.png
# Converted MNI_AD37.nii to ./Original_images\AD\MNI_AD37.png
# Converted MNI_AD38.nii to ./Original_images\AD\MNI_AD38.png
# Converted MNI_AD39.nii to ./Original_images\AD\MNI_AD39.png
# Converted MNI_AD4.nii to ./Original_images\AD\MNI_AD4.png
# Converted MNI_AD40.nii to ./Original_images\AD\MNI_AD40.png
# Converted MNI_AD41.nii to ./Original_images\AD\MNI_AD41.png
# Converted MNI_AD42.nii to ./Original_images\AD\MNI_AD42.png
# Converted MNI_AD43.nii to ./Original_images\AD\MNI_AD43.png
# Converted MNI_AD44.nii to ./Original_images\AD\MNI_AD44.png
# Converted MNI_AD45.nii to ./Original_images\AD\MNI_AD45.png
# Converted MNI_AD46.nii to ./Original_images\AD\MNI_AD46.png
# Converted MNI_AD47.nii to ./Original_images\AD\MNI_AD47.png
# Converted MNI_AD48.nii to ./Original_images\AD\MNI_AD48.png
# Converted MNI_AD49.nii to ./Original_images\AD\MNI_AD49.png
# Converted MNI_AD5.nii to ./Original_images\AD\MNI_AD5.png
# Converted MNI_AD50.nii to ./Original_images\AD\MNI_AD50.png
# Converted MNI_AD6.nii to ./Original_images\AD\MNI_AD6.png
# Converted MNI_AD7.nii to ./Original_images\AD\MNI_AD7.png
# Converted MNI_AD8.nii to ./Original_images\AD\MNI_AD8.png
# Converted MNI_AD9.nii to ./Original_images\AD\MNI_AD9.png
# Converted MNI_CN100.nii to ./Original_images\CN\MNI_CN100.png
# Converted MNI_CN51.nii to ./Original_images\CN\MNI_CN51.png
# Converted MNI_CN52.nii to ./Original_images\CN\MNI_CN52.png
# Converted MNI_CN53.nii to ./Original_images\CN\MNI_CN53.png
# Converted MNI_CN54.nii to ./Original_images\CN\MNI_CN54.png
# Converted MNI_CN55.nii to ./Original_images\CN\MNI_CN55.png
# Converted MNI_CN56.nii to ./Original_images\CN\MNI_CN56.png
# Converted MNI_CN57.nii to ./Original_images\CN\MNI_CN57.png
# Converted MNI_CN58.nii to ./Original_images\CN\MNI_CN58.png
# Converted MNI_CN59.nii to ./Original_images\CN\MNI_CN59.png
# Converted MNI_CN60.nii to ./Original_images\CN\MNI_CN60.png
# Converted MNI_CN61.nii to ./Original_images\CN\MNI_CN61.png
# Converted MNI_CN62.nii to ./Original_images\CN\MNI_CN62.png
# Converted MNI_CN63.nii to ./Original_images\CN\MNI_CN63.png
# Converted MNI_CN64.nii to ./Original_images\CN\MNI_CN64.png
# Converted MNI_CN65.nii to ./Original_images\CN\MNI_CN65.png
# Converted MNI_CN66.nii to ./Original_images\CN\MNI_CN66.png
# Converted MNI_CN67.nii to ./Original_images\CN\MNI_CN67.png
# Converted MNI_CN68.nii to ./Original_images\CN\MNI_CN68.png
# Converted MNI_CN69.nii to ./Original_images\CN\MNI_CN69.png
# Converted MNI_CN70.nii to ./Original_images\CN\MNI_CN70.png
# Converted MNI_CN71.nii to ./Original_images\CN\MNI_CN71.png
# Converted MNI_CN72.nii to ./Original_images\CN\MNI_CN72.png
# Converted MNI_CN73.nii to ./Original_images\CN\MNI_CN73.png
# Converted MNI_CN74.nii to ./Original_images\CN\MNI_CN74.png
# Converted MNI_CN75.nii to ./Original_images\CN\MNI_CN75.png
# Converted MNI_CN76.nii to ./Original_images\CN\MNI_CN76.png
# Converted MNI_CN77.nii to ./Original_images\CN\MNI_CN77.png
# Converted MNI_CN78.nii to ./Original_images\CN\MNI_CN78.png
# Converted MNI_CN79.nii to ./Original_images\CN\MNI_CN79.png
# Converted MNI_CN80.nii to ./Original_images\CN\MNI_CN80.png
# Converted MNI_CN81.nii to ./Original_images\CN\MNI_CN81.png
# Converted MNI_CN82.nii to ./Original_images\CN\MNI_CN82.png
# Converted MNI_CN83.nii to ./Original_images\CN\MNI_CN83.png
# Converted MNI_CN84.nii to ./Original_images\CN\MNI_CN84.png
# Converted MNI_CN85.nii to ./Original_images\CN\MNI_CN85.png
# Converted MNI_CN86.nii to ./Original_images\CN\MNI_CN86.png
# Converted MNI_CN87.nii to ./Original_images\CN\MNI_CN87.png
# Converted MNI_CN88.nii to ./Original_images\CN\MNI_CN88.png
# Converted MNI_CN89.nii to ./Original_images\CN\MNI_CN89.png
# Converted MNI_CN90.nii to ./Original_images\CN\MNI_CN90.png
# Converted MNI_CN91.nii to ./Original_images\CN\MNI_CN91.png
# Converted MNI_CN92.nii to ./Original_images\CN\MNI_CN92.png
# Converted MNI_CN93.nii to ./Original_images\CN\MNI_CN93.png
# Converted MNI_CN94.nii to ./Original_images\CN\MNI_CN94.png
# Converted MNI_CN95.nii to ./Original_images\CN\MNI_CN95.png
# Converted MNI_CN96.nii to ./Original_images\CN\MNI_CN96.png
# Converted MNI_CN97.nii to ./Original_images\CN\MNI_CN97.png
# Converted MNI_CN98.nii to ./Original_images\CN\MNI_CN98.png
# Converted MNI_CN99.nii to ./Original_images\CN\MNI_CN99.png
# Converted MNI_EMCI101.nii to ./Original_images\EMCI\MNI_EMCI101.png
# Converted MNI_EMCI102.nii to ./Original_images\EMCI\MNI_EMCI102.png
# Converted MNI_EMCI103.nii to ./Original_images\EMCI\MNI_EMCI103.png
# Converted MNI_EMCI104.nii to ./Original_images\EMCI\MNI_EMCI104.png
# Converted MNI_EMCI105.nii to ./Original_images\EMCI\MNI_EMCI105.png
# Converted MNI_EMCI106.nii to ./Original_images\EMCI\MNI_EMCI106.png
# Converted MNI_EMCI107.nii to ./Original_images\EMCI\MNI_EMCI107.png
# Converted MNI_EMCI108.nii to ./Original_images\EMCI\MNI_EMCI108.png
# Converted MNI_EMCI109.nii to ./Original_images\EMCI\MNI_EMCI109.png
# Converted MNI_EMCI110.nii to ./Original_images\EMCI\MNI_EMCI110.png
# Converted MNI_EMCI111.nii to ./Original_images\EMCI\MNI_EMCI111.png
# Converted MNI_EMCI112.nii to ./Original_images\EMCI\MNI_EMCI112.png
# Converted MNI_EMCI113.nii to ./Original_images\EMCI\MNI_EMCI113.png
# Converted MNI_EMCI114.nii to ./Original_images\EMCI\MNI_EMCI114.png
# Converted MNI_EMCI115.nii to ./Original_images\EMCI\MNI_EMCI115.png
# Converted MNI_EMCI116.nii to ./Original_images\EMCI\MNI_EMCI116.png
# Converted MNI_EMCI117.nii to ./Original_images\EMCI\MNI_EMCI117.png
# Converted MNI_EMCI118.nii to ./Original_images\EMCI\MNI_EMCI118.png
# Converted MNI_EMCI119.nii to ./Original_images\EMCI\MNI_EMCI119.png
# Converted MNI_EMCI120.nii to ./Original_images\EMCI\MNI_EMCI120.png
# Converted MNI_EMCI121.nii to ./Original_images\EMCI\MNI_EMCI121.png
# Converted MNI_EMCI122.nii to ./Original_images\EMCI\MNI_EMCI122.png
# Converted MNI_EMCI123.nii to ./Original_images\EMCI\MNI_EMCI123.png
# Converted MNI_EMCI124.nii to ./Original_images\EMCI\MNI_EMCI124.png
# Converted MNI_EMCI125.nii to ./Original_images\EMCI\MNI_EMCI125.png
# Converted MNI_EMCI126.nii to ./Original_images\EMCI\MNI_EMCI126.png
# Converted MNI_EMCI127.nii to ./Original_images\EMCI\MNI_EMCI127.png
# Converted MNI_EMCI128.nii to ./Original_images\EMCI\MNI_EMCI128.png
# Converted MNI_EMCI129.nii to ./Original_images\EMCI\MNI_EMCI129.png
# Converted MNI_EMCI130.nii to ./Original_images\EMCI\MNI_EMCI130.png
# Converted MNI_EMCI131.nii to ./Original_images\EMCI\MNI_EMCI131.png
# Converted MNI_EMCI132.nii to ./Original_images\EMCI\MNI_EMCI132.png
# Converted MNI_EMCI133.nii to ./Original_images\EMCI\MNI_EMCI133.png
# Converted MNI_EMCI134.nii to ./Original_images\EMCI\MNI_EMCI134.png
# Converted MNI_EMCI135.nii to ./Original_images\EMCI\MNI_EMCI135.png
# Converted MNI_EMCI136.nii to ./Original_images\EMCI\MNI_EMCI136.png
# Converted MNI_EMCI137.nii to ./Original_images\EMCI\MNI_EMCI137.png
# Converted MNI_EMCI138.nii to ./Original_images\EMCI\MNI_EMCI138.png
# Converted MNI_EMCI139.nii to ./Original_images\EMCI\MNI_EMCI139.png
# Converted MNI_EMCI140.nii to ./Original_images\EMCI\MNI_EMCI140.png
# Converted MNI_EMCI141.nii to ./Original_images\EMCI\MNI_EMCI141.png
# Converted MNI_EMCI142.nii to ./Original_images\EMCI\MNI_EMCI142.png
# Converted MNI_EMCI143.nii to ./Original_images\EMCI\MNI_EMCI143.png
# Converted MNI_EMCI144.nii to ./Original_images\EMCI\MNI_EMCI144.png
# Converted MNI_EMCI145.nii to ./Original_images\EMCI\MNI_EMCI145.png
# Converted MNI_EMCI146.nii to ./Original_images\EMCI\MNI_EMCI146.png
# Converted MNI_EMCI147.nii to ./Original_images\EMCI\MNI_EMCI147.png
# Converted MNI_EMCI148.nii to ./Original_images\EMCI\MNI_EMCI148.png
# Converted MNI_EMCI149.nii to ./Original_images\EMCI\MNI_EMCI149.png
# Converted MNI_EMCI150.nii to ./Original_images\EMCI\MNI_EMCI150.png
# Converted MNI_LMCI151.nii to ./Original_images\LMCI\MNI_LMCI151.png
# Converted MNI_LMCI152.nii to ./Original_images\LMCI\MNI_LMCI152.png
# Converted MNI_LMCI153.nii to ./Original_images\LMCI\MNI_LMCI153.png
# Converted MNI_LMCI154.nii to ./Original_images\LMCI\MNI_LMCI154.png
# Converted MNI_LMCI155.nii to ./Original_images\LMCI\MNI_LMCI155.png
# Converted MNI_LMCI156.nii to ./Original_images\LMCI\MNI_LMCI156.png
# Converted MNI_LMCI157.nii to ./Original_images\LMCI\MNI_LMCI157.png
# Converted MNI_LMCI158.nii to ./Original_images\LMCI\MNI_LMCI158.png
# Converted MNI_LMCI159.nii to ./Original_images\LMCI\MNI_LMCI159.png
# Converted MNI_LMCI160.nii to ./Original_images\LMCI\MNI_LMCI160.png
# Converted MNI_LMCI161.nii to ./Original_images\LMCI\MNI_LMCI161.png
# Converted MNI_LMCI162.nii to ./Original_images\LMCI\MNI_LMCI162.png
# Converted MNI_LMCI163.nii to ./Original_images\LMCI\MNI_LMCI163.png
# Converted MNI_LMCI164.nii to ./Original_images\LMCI\MNI_LMCI164.png
# Converted MNI_LMCI165.nii to ./Original_images\LMCI\MNI_LMCI165.png
# Converted MNI_LMCI166.nii to ./Original_images\LMCI\MNI_LMCI166.png
# Converted MNI_LMCI167.nii to ./Original_images\LMCI\MNI_LMCI167.png
# Converted MNI_LMCI168.nii to ./Original_images\LMCI\MNI_LMCI168.png
# Converted MNI_LMCI169.nii to ./Original_images\LMCI\MNI_LMCI169.png
# Converted MNI_LMCI170.nii to ./Original_images\LMCI\MNI_LMCI170.png
# Converted MNI_LMCI171.nii to ./Original_images\LMCI\MNI_LMCI171.png
# Converted MNI_LMCI172.nii to ./Original_images\LMCI\MNI_LMCI172.png
# Converted MNI_LMCI173.nii to ./Original_images\LMCI\MNI_LMCI173.png
# Converted MNI_LMCI174.nii to ./Original_images\LMCI\MNI_LMCI174.png
# Converted MNI_LMCI175.nii to ./Original_images\LMCI\MNI_LMCI175.png
# Converted MNI_LMCI176.nii to ./Original_images\LMCI\MNI_LMCI176.png
# Converted MNI_LMCI177.nii to ./Original_images\LMCI\MNI_LMCI177.png
# Converted MNI_LMCI178.nii to ./Original_images\LMCI\MNI_LMCI178.png
# Converted MNI_LMCI179.nii to ./Original_images\LMCI\MNI_LMCI179.png
# Converted MNI_LMCI180.nii to ./Original_images\LMCI\MNI_LMCI180.png
# Converted MNI_LMCI181.nii to ./Original_images\LMCI\MNI_LMCI181.png
# Converted MNI_LMCI182.nii to ./Original_images\LMCI\MNI_LMCI182.png
# Converted MNI_LMCI183.nii to ./Original_images\LMCI\MNI_LMCI183.png
# Converted MNI_LMCI184.nii to ./Original_images\LMCI\MNI_LMCI184.png
# Converted MNI_LMCI185.nii to ./Original_images\LMCI\MNI_LMCI185.png
# Converted MNI_LMCI186.nii to ./Original_images\LMCI\MNI_LMCI186.png
# Converted MNI_LMCI187.nii to ./Original_images\LMCI\MNI_LMCI187.png
# Converted MNI_LMCI188.nii to ./Original_images\LMCI\MNI_LMCI188.png
# Converted MNI_LMCI189.nii to ./Original_images\LMCI\MNI_LMCI189.png
# Converted MNI_LMCI190.nii to ./Original_images\LMCI\MNI_LMCI190.png
# Converted MNI_LMCI191.nii to ./Original_images\LMCI\MNI_LMCI191.png
# Converted MNI_LMCI192.nii to ./Original_images\LMCI\MNI_LMCI192.png
# Converted MNI_LMCI193.nii to ./Original_images\LMCI\MNI_LMCI193.png
# Converted MNI_LMCI194.nii to ./Original_images\LMCI\MNI_LMCI194.png
# Converted MNI_LMCI195.nii to ./Original_images\LMCI\MNI_LMCI195.png
# Converted MNI_LMCI196.nii to ./Original_images\LMCI\MNI_LMCI196.png
# Converted MNI_LMCI197.nii to ./Original_images\LMCI\MNI_LMCI197.png
# Converted MNI_LMCI198.nii to ./Original_images\LMCI\MNI_LMCI198.png
# Converted MNI_LMCI199.nii to ./Original_images\LMCI\MNI_LMCI199.png
# Converted MNI_LMCI200.nii to ./Original_images\LMCI\MNI_LMCI200.png
# Converted MNI_MCI201.nii to ./Original_images\MCI\MNI_MCI201.png
# Converted MNI_MCI202.nii to ./Original_images\MCI\MNI_MCI202.png
# Converted MNI_MCI203.nii to ./Original_images\MCI\MNI_MCI203.png
# Converted MNI_MCI204.nii to ./Original_images\MCI\MNI_MCI204.png
# Converted MNI_MCI205.nii to ./Original_images\MCI\MNI_MCI205.png
# Converted MNI_MCI206.nii to ./Original_images\MCI\MNI_MCI206.png
# Converted MNI_MCI207.nii to ./Original_images\MCI\MNI_MCI207.png
# Converted MNI_MCI208.nii to ./Original_images\MCI\MNI_MCI208.png
# Converted MNI_MCI209.nii to ./Original_images\MCI\MNI_MCI209.png
# Converted MNI_MCI210.nii to ./Original_images\MCI\MNI_MCI210.png
# Converted MNI_MCI211.nii to ./Original_images\MCI\MNI_MCI211.png
# Converted MNI_MCI212.nii to ./Original_images\MCI\MNI_MCI212.png
# Converted MNI_MCI213.nii to ./Original_images\MCI\MNI_MCI213.png
# Converted MNI_MCI214.nii to ./Original_images\MCI\MNI_MCI214.png
# Converted MNI_MCI215.nii to ./Original_images\MCI\MNI_MCI215.png
# Converted MNI_MCI216.nii to ./Original_images\MCI\MNI_MCI216.png
# Converted MNI_MCI217.nii to ./Original_images\MCI\MNI_MCI217.png
# Converted MNI_MCI218.nii to ./Original_images\MCI\MNI_MCI218.png
# Converted MNI_MCI219.nii to ./Original_images\MCI\MNI_MCI219.png
# Converted MNI_MCI220.nii to ./Original_images\MCI\MNI_MCI220.png
# Converted MNI_MCI221.nii to ./Original_images\MCI\MNI_MCI221.png
# Converted MNI_MCI222.nii to ./Original_images\MCI\MNI_MCI222.png
# Converted MNI_MCI223.nii to ./Original_images\MCI\MNI_MCI223.png
# Converted MNI_MCI224.nii to ./Original_images\MCI\MNI_MCI224.png
# Converted MNI_MCI225.nii to ./Original_images\MCI\MNI_MCI225.png
# Converted MNI_MCI226.nii to ./Original_images\MCI\MNI_MCI226.png
# Converted MNI_MCI227.nii to ./Original_images\MCI\MNI_MCI227.png
# Converted MNI_MCI228.nii to ./Original_images\MCI\MNI_MCI228.png
# Converted MNI_MCI229.nii to ./Original_images\MCI\MNI_MCI229.png
# Converted MNI_MCI230.nii to ./Original_images\MCI\MNI_MCI230.png
# Converted MNI_MCI231.nii to ./Original_images\MCI\MNI_MCI231.png
# Converted MNI_MCI232.nii to ./Original_images\MCI\MNI_MCI232.png
# Converted MNI_MCI233.nii to ./Original_images\MCI\MNI_MCI233.png
# Converted MNI_MCI234.nii to ./Original_images\MCI\MNI_MCI234.png
# Converted MNI_MCI235.nii to ./Original_images\MCI\MNI_MCI235.png
# Converted MNI_MCI236.nii to ./Original_images\MCI\MNI_MCI236.png
# Converted MNI_MCI237.nii to ./Original_images\MCI\MNI_MCI237.png
# Converted MNI_MCI238.nii to ./Original_images\MCI\MNI_MCI238.png
# Converted MNI_MCI239.nii to ./Original_images\MCI\MNI_MCI239.png
# Converted MNI_MCI240.nii to ./Original_images\MCI\MNI_MCI240.png
# Converted MNI_MCI241.nii to ./Original_images\MCI\MNI_MCI241.png
# Converted MNI_MCI242.nii to ./Original_images\MCI\MNI_MCI242.png
# Converted MNI_MCI243.nii to ./Original_images\MCI\MNI_MCI243.png
# Converted MNI_MCI244.nii to ./Original_images\MCI\MNI_MCI244.png
# Converted MNI_MCI245.nii to ./Original_images\MCI\MNI_MCI245.png
# Converted MNI_MCI246.nii to ./Original_images\MCI\MNI_MCI246.png
# Converted MNI_MCI247.nii to ./Original_images\MCI\MNI_MCI247.png
# Converted MNI_MCI248.nii to ./Original_images\MCI\MNI_MCI248.png
# Converted MNI_MCI249.nii to ./Original_images\MCI\MNI_MCI249.png
# Converted MNI_MCI250.nii to ./Original_images\MCI\MNI_MCI250.png
# Conversion completed.

# %%
# import os
# import nibabel as nib
# import imageio
# import numpy as np
# import re
# import cv2

# # Create output folders if they don't exist
# classes = ['AD', 'CN', 'EMCI', 'LMCI', 'MCI']
# for cls in classes:
#     os.makedirs(os.path.join(output_folder, cls), exist_ok=True)

# # Function to enhance image
# def enhance_image(image):
#     # Apply histogram equalization
#     image = cv2.equalizeHist(image)
#     # Apply sharpening
#     kernel = np.array([[0, -1, 0],
#                        [-1, 5,-1],
#                        [0, -1, 0]])
#     image = cv2.filter2D(image, -1, kernel)
#     return image

# # Function to resize image
# def resize_image(image, scale_percent):
#     width = int(image.shape[1] * scale_percent / 100)
#     height = int(image.shape[0] * scale_percent / 100)
#     dim = (width, height)
#     # Resize image
#     resized = cv2.resize(image, dim, interpolation = cv2.INTER_CUBIC)
#     return resized

# # Function to convert nii to png or jpeg
# def nii_to_image(nii_file, output_file, scale_percent=200):
#     img = nib.load(nii_file)
#     img_data = img.get_fdata()
#     # Extract the middle slice of the 3D image data
#     middle_slice = img_data[:, :, img_data.shape[2] // 2]
#     # Normalize the data to the range [0, 255] for saving as an image
#     middle_slice = (255 * (middle_slice - np.min(middle_slice)) / (np.max(middle_slice) - np.min(middle_slice))).astype(np.uint8)
#     # Enhance the image
#     enhanced_image = enhance_image(middle_slice)
#     # Resize the image
#     resized_image = resize_image(enhanced_image, scale_percent)
#     # Save the image
#     imageio.imwrite(output_file, resized_image)

# # Regular expression pattern to match filenames like MNI_AD1.nii, MNI_CN89.nii, etc.
# pattern = re.compile(r'MNI_(AD|CN|EMCI|LMCI|MCI)\d+\.nii')

# # Process each nii file
# for filename in os.listdir(input_folder):
#     if pattern.match(filename):
#         file_path = os.path.join(input_folder, filename)
#         class_name = re.search(r'MNI_(AD|CN|EMCI|LMCI|MCI)', filename).group(1)
#         output_file = os.path.join(output_folder, class_name, filename.replace('.nii', '.png'))
#         nii_to_image(file_path, output_file)
#         print(f'Converted {filename} to {output_file}')

# print("Conversion completed.")
# Out:
# Converted MNI_AD1.nii to ./process_data\AD\MNI_AD1.png
# Converted MNI_AD10.nii to ./process_data\AD\MNI_AD10.png
# Converted MNI_AD11.nii to ./process_data\AD\MNI_AD11.png
# Converted MNI_AD12.nii to ./process_data\AD\MNI_AD12.png
# Converted MNI_AD13.nii to ./process_data\AD\MNI_AD13.png
# Converted MNI_AD14.nii to ./process_data\AD\MNI_AD14.png
# Converted MNI_AD15.nii to ./process_data\AD\MNI_AD15.png
# Converted MNI_AD16.nii to ./process_data\AD\MNI_AD16.png
# Converted MNI_AD17.nii to ./process_data\AD\MNI_AD17.png
# Converted MNI_AD18.nii to ./process_data\AD\MNI_AD18.png
# Converted MNI_AD19.nii to ./process_data\AD\MNI_AD19.png
# Converted MNI_AD2.nii to ./process_data\AD\MNI_AD2.png
# Converted MNI_AD20.nii to ./process_data\AD\MNI_AD20.png
# Converted MNI_AD21.nii to ./process_data\AD\MNI_AD21.png
# Converted MNI_AD22.nii to ./process_data\AD\MNI_AD22.png
# Converted MNI_AD23.nii to ./process_data\AD\MNI_AD23.png
# Converted MNI_AD24.nii to ./process_data\AD\MNI_AD24.png
# Converted MNI_AD25.nii to ./process_data\AD\MNI_AD25.png
# Converted MNI_AD26.nii to ./process_data\AD\MNI_AD26.png
# Converted MNI_AD27.nii to ./process_data\AD\MNI_AD27.png
# Converted MNI_AD28.nii to ./process_data\AD\MNI_AD28.png
# Converted MNI_AD29.nii to ./process_data\AD\MNI_AD29.png
# Converted MNI_AD3.nii to ./process_data\AD\MNI_AD3.png
# Converted MNI_AD30.nii to ./process_data\AD\MNI_AD30.png
# Converted MNI_AD31.nii to ./process_data\AD\MNI_AD31.png
# Converted MNI_AD32.nii to ./process_data\AD\MNI_AD32.png
# Converted MNI_AD33.nii to ./process_data\AD\MNI_AD33.png
# Converted MNI_AD34.nii to ./process_data\AD\MNI_AD34.png
# Converted MNI_AD35.nii to ./process_data\AD\MNI_AD35.png
# Converted MNI_AD36.nii to ./process_data\AD\MNI_AD36.png
# Converted MNI_AD37.nii to ./process_data\AD\MNI_AD37.png
# Converted MNI_AD38.nii to ./process_data\AD\MNI_AD38.png
# Converted MNI_AD39.nii to ./process_data\AD\MNI_AD39.png
# Converted MNI_AD4.nii to ./process_data\AD\MNI_AD4.png
# Converted MNI_AD40.nii to ./process_data\AD\MNI_AD40.png
# Converted MNI_AD41.nii to ./process_data\AD\MNI_AD41.png
# Converted MNI_AD42.nii to ./process_data\AD\MNI_AD42.png
# Converted MNI_AD43.nii to ./process_data\AD\MNI_AD43.png
# Converted MNI_AD44.nii to ./process_data\AD\MNI_AD44.png
# Converted MNI_AD45.nii to ./process_data\AD\MNI_AD45.png
# Converted MNI_AD46.nii to ./process_data\AD\MNI_AD46.png
# Converted MNI_AD47.nii to ./process_data\AD\MNI_AD47.png
# Converted MNI_AD48.nii to ./process_data\AD\MNI_AD48.png
# Converted MNI_AD49.nii to ./process_data\AD\MNI_AD49.png
# Converted MNI_AD5.nii to ./process_data\AD\MNI_AD5.png
# Converted MNI_AD50.nii to ./process_data\AD\MNI_AD50.png
# Converted MNI_AD6.nii to ./process_data\AD\MNI_AD6.png
# Converted MNI_AD7.nii to ./process_data\AD\MNI_AD7.png
# Converted MNI_AD8.nii to ./process_data\AD\MNI_AD8.png
# Converted MNI_AD9.nii to ./process_data\AD\MNI_AD9.png
# Converted MNI_CN100.nii to ./process_data\CN\MNI_CN100.png
# Converted MNI_CN51.nii to ./process_data\CN\MNI_CN51.png
# Converted MNI_CN52.nii to ./process_data\CN\MNI_CN52.png
# Converted MNI_CN53.nii to ./process_data\CN\MNI_CN53.png
# Converted MNI_CN54.nii to ./process_data\CN\MNI_CN54.png
# Converted MNI_CN55.nii to ./process_data\CN\MNI_CN55.png
# Converted MNI_CN56.nii to ./process_data\CN\MNI_CN56.png
# Converted MNI_CN57.nii to ./process_data\CN\MNI_CN57.png
# Converted MNI_CN58.nii to ./process_data\CN\MNI_CN58.png
# Converted MNI_CN59.nii to ./process_data\CN\MNI_CN59.png
# Converted MNI_CN60.nii to ./process_data\CN\MNI_CN60.png
# Converted MNI_CN61.nii to ./process_data\CN\MNI_CN61.png
# Converted MNI_CN62.nii to ./process_data\CN\MNI_CN62.png
# Converted MNI_CN63.nii to ./process_data\CN\MNI_CN63.png
# Converted MNI_CN64.nii to ./process_data\CN\MNI_CN64.png
# Converted MNI_CN65.nii to ./process_data\CN\MNI_CN65.png
# Converted MNI_CN66.nii to ./process_data\CN\MNI_CN66.png
# Converted MNI_CN67.nii to ./process_data\CN\MNI_CN67.png
# Converted MNI_CN68.nii to ./process_data\CN\MNI_CN68.png
# Converted MNI_CN69.nii to ./process_data\CN\MNI_CN69.png
# Converted MNI_CN70.nii to ./process_data\CN\MNI_CN70.png
# Converted MNI_CN71.nii to ./process_data\CN\MNI_CN71.png
# Converted MNI_CN72.nii to ./process_data\CN\MNI_CN72.png
# Converted MNI_CN73.nii to ./process_data\CN\MNI_CN73.png
# Converted MNI_CN74.nii to ./process_data\CN\MNI_CN74.png
# Converted MNI_CN75.nii to ./process_data\CN\MNI_CN75.png
# Converted MNI_CN76.nii to ./process_data\CN\MNI_CN76.png
# Converted MNI_CN77.nii to ./process_data\CN\MNI_CN77.png
# Converted MNI_CN78.nii to ./process_data\CN\MNI_CN78.png
# Converted MNI_CN79.nii to ./process_data\CN\MNI_CN79.png
# Converted MNI_CN80.nii to ./process_data\CN\MNI_CN80.png
# Converted MNI_CN81.nii to ./process_data\CN\MNI_CN81.png
# Converted MNI_CN82.nii to ./process_data\CN\MNI_CN82.png
# Converted MNI_CN83.nii to ./process_data\CN\MNI_CN83.png
# Converted MNI_CN84.nii to ./process_data\CN\MNI_CN84.png
# Converted MNI_CN85.nii to ./process_data\CN\MNI_CN85.png
# Converted MNI_CN86.nii to ./process_data\CN\MNI_CN86.png
# Converted MNI_CN87.nii to ./process_data\CN\MNI_CN87.png
# Converted MNI_CN88.nii to ./process_data\CN\MNI_CN88.png
# Converted MNI_CN89.nii to ./process_data\CN\MNI_CN89.png
# Converted MNI_CN90.nii to ./process_data\CN\MNI_CN90.png
# Converted MNI_CN91.nii to ./process_data\CN\MNI_CN91.png
# Converted MNI_CN92.nii to ./process_data\CN\MNI_CN92.png
# Converted MNI_CN93.nii to ./process_data\CN\MNI_CN93.png
# Converted MNI_CN94.nii to ./process_data\CN\MNI_CN94.png
# Converted MNI_CN95.nii to ./process_data\CN\MNI_CN95.png
# Converted MNI_CN96.nii to ./process_data\CN\MNI_CN96.png
# Converted MNI_CN97.nii to ./process_data\CN\MNI_CN97.png
# Converted MNI_CN98.nii to ./process_data\CN\MNI_CN98.png
# Converted MNI_CN99.nii to ./process_data\CN\MNI_CN99.png
# Converted MNI_EMCI101.nii to ./process_data\EMCI\MNI_EMCI101.png
# Converted MNI_EMCI102.nii to ./process_data\EMCI\MNI_EMCI102.png
# Converted MNI_EMCI103.nii to ./process_data\EMCI\MNI_EMCI103.png
# Converted MNI_EMCI104.nii to ./process_data\EMCI\MNI_EMCI104.png
# Converted MNI_EMCI105.nii to ./process_data\EMCI\MNI_EMCI105.png
# Converted MNI_EMCI106.nii to ./process_data\EMCI\MNI_EMCI106.png
# Converted MNI_EMCI107.nii to ./process_data\EMCI\MNI_EMCI107.png
# Converted MNI_EMCI108.nii to ./process_data\EMCI\MNI_EMCI108.png
# Converted MNI_EMCI109.nii to ./process_data\EMCI\MNI_EMCI109.png
# Converted MNI_EMCI110.nii to ./process_data\EMCI\MNI_EMCI110.png
# Converted MNI_EMCI111.nii to ./process_data\EMCI\MNI_EMCI111.png
# Converted MNI_EMCI112.nii to ./process_data\EMCI\MNI_EMCI112.png
# Converted MNI_EMCI113.nii to ./process_data\EMCI\MNI_EMCI113.png
# Converted MNI_EMCI114.nii to ./process_data\EMCI\MNI_EMCI114.png
# Converted MNI_EMCI115.nii to ./process_data\EMCI\MNI_EMCI115.png
# Converted MNI_EMCI116.nii to ./process_data\EMCI\MNI_EMCI116.png
# Converted MNI_EMCI117.nii to ./process_data\EMCI\MNI_EMCI117.png
# Converted MNI_EMCI118.nii to ./process_data\EMCI\MNI_EMCI118.png
# Converted MNI_EMCI119.nii to ./process_data\EMCI\MNI_EMCI119.png
# Converted MNI_EMCI120.nii to ./process_data\EMCI\MNI_EMCI120.png
# Converted MNI_EMCI121.nii to ./process_data\EMCI\MNI_EMCI121.png
# Converted MNI_EMCI122.nii to ./process_data\EMCI\MNI_EMCI122.png
# Converted MNI_EMCI123.nii to ./process_data\EMCI\MNI_EMCI123.png
# Converted MNI_EMCI124.nii to ./process_data\EMCI\MNI_EMCI124.png
# Converted MNI_EMCI125.nii to ./process_data\EMCI\MNI_EMCI125.png
# Converted MNI_EMCI126.nii to ./process_data\EMCI\MNI_EMCI126.png
# Converted MNI_EMCI127.nii to ./process_data\EMCI\MNI_EMCI127.png
# Converted MNI_EMCI128.nii to ./process_data\EMCI\MNI_EMCI128.png
# Converted MNI_EMCI129.nii to ./process_data\EMCI\MNI_EMCI129.png
# Converted MNI_EMCI130.nii to ./process_data\EMCI\MNI_EMCI130.png
# Converted MNI_EMCI131.nii to ./process_data\EMCI\MNI_EMCI131.png
# Converted MNI_EMCI132.nii to ./process_data\EMCI\MNI_EMCI132.png
# Converted MNI_EMCI133.nii to ./process_data\EMCI\MNI_EMCI133.png
# Converted MNI_EMCI134.nii to ./process_data\EMCI\MNI_EMCI134.png
# Converted MNI_EMCI135.nii to ./process_data\EMCI\MNI_EMCI135.png
# Converted MNI_EMCI136.nii to ./process_data\EMCI\MNI_EMCI136.png
# Converted MNI_EMCI137.nii to ./process_data\EMCI\MNI_EMCI137.png
# Converted MNI_EMCI138.nii to ./process_data\EMCI\MNI_EMCI138.png
# Converted MNI_EMCI139.nii to ./process_data\EMCI\MNI_EMCI139.png
# Converted MNI_EMCI140.nii to ./process_data\EMCI\MNI_EMCI140.png
# Converted MNI_EMCI141.nii to ./process_data\EMCI\MNI_EMCI141.png
# Converted MNI_EMCI142.nii to ./process_data\EMCI\MNI_EMCI142.png
# Converted MNI_EMCI143.nii to ./process_data\EMCI\MNI_EMCI143.png
# Converted MNI_EMCI144.nii to ./process_data\EMCI\MNI_EMCI144.png
# Converted MNI_EMCI145.nii to ./process_data\EMCI\MNI_EMCI145.png
# Converted MNI_EMCI146.nii to ./process_data\EMCI\MNI_EMCI146.png
# Converted MNI_EMCI147.nii to ./process_data\EMCI\MNI_EMCI147.png
# Converted MNI_EMCI148.nii to ./process_data\EMCI\MNI_EMCI148.png
# Converted MNI_EMCI149.nii to ./process_data\EMCI\MNI_EMCI149.png
# Converted MNI_EMCI150.nii to ./process_data\EMCI\MNI_EMCI150.png
# Converted MNI_LMCI151.nii to ./process_data\LMCI\MNI_LMCI151.png
# Converted MNI_LMCI152.nii to ./process_data\LMCI\MNI_LMCI152.png
# Converted MNI_LMCI153.nii to ./process_data\LMCI\MNI_LMCI153.png
# Converted MNI_LMCI154.nii to ./process_data\LMCI\MNI_LMCI154.png
# Converted MNI_LMCI155.nii to ./process_data\LMCI\MNI_LMCI155.png
# Converted MNI_LMCI156.nii to ./process_data\LMCI\MNI_LMCI156.png
# Converted MNI_LMCI157.nii to ./process_data\LMCI\MNI_LMCI157.png
# Converted MNI_LMCI158.nii to ./process_data\LMCI\MNI_LMCI158.png
# Converted MNI_LMCI159.nii to ./process_data\LMCI\MNI_LMCI159.png
# Converted MNI_LMCI160.nii to ./process_data\LMCI\MNI_LMCI160.png
# Converted MNI_LMCI161.nii to ./process_data\LMCI\MNI_LMCI161.png
# Converted MNI_LMCI162.nii to ./process_data\LMCI\MNI_LMCI162.png
# Converted MNI_LMCI163.nii to ./process_data\LMCI\MNI_LMCI163.png
# Converted MNI_LMCI164.nii to ./process_data\LMCI\MNI_LMCI164.png
# Converted MNI_LMCI165.nii to ./process_data\LMCI\MNI_LMCI165.png
# Converted MNI_LMCI166.nii to ./process_data\LMCI\MNI_LMCI166.png
# Converted MNI_LMCI167.nii to ./process_data\LMCI\MNI_LMCI167.png
# Converted MNI_LMCI168.nii to ./process_data\LMCI\MNI_LMCI168.png
# Converted MNI_LMCI169.nii to ./process_data\LMCI\MNI_LMCI169.png
# Converted MNI_LMCI170.nii to ./process_data\LMCI\MNI_LMCI170.png
# Converted MNI_LMCI171.nii to ./process_data\LMCI\MNI_LMCI171.png
# Converted MNI_LMCI172.nii to ./process_data\LMCI\MNI_LMCI172.png
# Converted MNI_LMCI173.nii to ./process_data\LMCI\MNI_LMCI173.png
# Converted MNI_LMCI174.nii to ./process_data\LMCI\MNI_LMCI174.png
# Converted MNI_LMCI175.nii to ./process_data\LMCI\MNI_LMCI175.png
# Converted MNI_LMCI176.nii to ./process_data\LMCI\MNI_LMCI176.png
# Converted MNI_LMCI177.nii to ./process_data\LMCI\MNI_LMCI177.png
# Converted MNI_LMCI178.nii to ./process_data\LMCI\MNI_LMCI178.png
# Converted MNI_LMCI179.nii to ./process_data\LMCI\MNI_LMCI179.png
# Converted MNI_LMCI180.nii to ./process_data\LMCI\MNI_LMCI180.png
# Converted MNI_LMCI181.nii to ./process_data\LMCI\MNI_LMCI181.png
# Converted MNI_LMCI182.nii to ./process_data\LMCI\MNI_LMCI182.png
# Converted MNI_LMCI183.nii to ./process_data\LMCI\MNI_LMCI183.png
# Converted MNI_LMCI184.nii to ./process_data\LMCI\MNI_LMCI184.png
# Converted MNI_LMCI185.nii to ./process_data\LMCI\MNI_LMCI185.png
# Converted MNI_LMCI186.nii to ./process_data\LMCI\MNI_LMCI186.png
# Converted MNI_LMCI187.nii to ./process_data\LMCI\MNI_LMCI187.png
# Converted MNI_LMCI188.nii to ./process_data\LMCI\MNI_LMCI188.png
# Converted MNI_LMCI189.nii to ./process_data\LMCI\MNI_LMCI189.png
# Converted MNI_LMCI190.nii to ./process_data\LMCI\MNI_LMCI190.png
# Converted MNI_LMCI191.nii to ./process_data\LMCI\MNI_LMCI191.png
# Converted MNI_LMCI192.nii to ./process_data\LMCI\MNI_LMCI192.png
# Converted MNI_LMCI193.nii to ./process_data\LMCI\MNI_LMCI193.png
# Converted MNI_LMCI194.nii to ./process_data\LMCI\MNI_LMCI194.png
# Converted MNI_LMCI195.nii to ./process_data\LMCI\MNI_LMCI195.png
# Converted MNI_LMCI196.nii to ./process_data\LMCI\MNI_LMCI196.png
# Converted MNI_LMCI197.nii to ./process_data\LMCI\MNI_LMCI197.png
# Converted MNI_LMCI198.nii to ./process_data\LMCI\MNI_LMCI198.png
# Converted MNI_LMCI199.nii to ./process_data\LMCI\MNI_LMCI199.png
# Converted MNI_LMCI200.nii to ./process_data\LMCI\MNI_LMCI200.png
# Converted MNI_MCI201.nii to ./process_data\MCI\MNI_MCI201.png
# Converted MNI_MCI202.nii to ./process_data\MCI\MNI_MCI202.png
# Converted MNI_MCI203.nii to ./process_data\MCI\MNI_MCI203.png
# Converted MNI_MCI204.nii to ./process_data\MCI\MNI_MCI204.png
# Converted MNI_MCI205.nii to ./process_data\MCI\MNI_MCI205.png
# Converted MNI_MCI206.nii to ./process_data\MCI\MNI_MCI206.png
# Converted MNI_MCI207.nii to ./process_data\MCI\MNI_MCI207.png
# Converted MNI_MCI208.nii to ./process_data\MCI\MNI_MCI208.png
# Converted MNI_MCI209.nii to ./process_data\MCI\MNI_MCI209.png
# Converted MNI_MCI210.nii to ./process_data\MCI\MNI_MCI210.png
# Converted MNI_MCI211.nii to ./process_data\MCI\MNI_MCI211.png
# Converted MNI_MCI212.nii to ./process_data\MCI\MNI_MCI212.png
# Converted MNI_MCI213.nii to ./process_data\MCI\MNI_MCI213.png
# Converted MNI_MCI214.nii to ./process_data\MCI\MNI_MCI214.png
# Converted MNI_MCI215.nii to ./process_data\MCI\MNI_MCI215.png
# Converted MNI_MCI216.nii to ./process_data\MCI\MNI_MCI216.png
# Converted MNI_MCI217.nii to ./process_data\MCI\MNI_MCI217.png
# Converted MNI_MCI218.nii to ./process_data\MCI\MNI_MCI218.png
# Converted MNI_MCI219.nii to ./process_data\MCI\MNI_MCI219.png
# Converted MNI_MCI220.nii to ./process_data\MCI\MNI_MCI220.png
# Converted MNI_MCI221.nii to ./process_data\MCI\MNI_MCI221.png
# Converted MNI_MCI222.nii to ./process_data\MCI\MNI_MCI222.png
# Converted MNI_MCI223.nii to ./process_data\MCI\MNI_MCI223.png
# Converted MNI_MCI224.nii to ./process_data\MCI\MNI_MCI224.png
# Converted MNI_MCI225.nii to ./process_data\MCI\MNI_MCI225.png
# Converted MNI_MCI226.nii to ./process_data\MCI\MNI_MCI226.png
# Converted MNI_MCI227.nii to ./process_data\MCI\MNI_MCI227.png
# Converted MNI_MCI228.nii to ./process_data\MCI\MNI_MCI228.png
# Converted MNI_MCI229.nii to ./process_data\MCI\MNI_MCI229.png
# Converted MNI_MCI230.nii to ./process_data\MCI\MNI_MCI230.png
# Converted MNI_MCI231.nii to ./process_data\MCI\MNI_MCI231.png
# Converted MNI_MCI232.nii to ./process_data\MCI\MNI_MCI232.png
# Converted MNI_MCI233.nii to ./process_data\MCI\MNI_MCI233.png
# Converted MNI_MCI234.nii to ./process_data\MCI\MNI_MCI234.png
# Converted MNI_MCI235.nii to ./process_data\MCI\MNI_MCI235.png
# Converted MNI_MCI236.nii to ./process_data\MCI\MNI_MCI236.png
# Converted MNI_MCI237.nii to ./process_data\MCI\MNI_MCI237.png
# Converted MNI_MCI238.nii to ./process_data\MCI\MNI_MCI238.png
# Converted MNI_MCI239.nii to ./process_data\MCI\MNI_MCI239.png
# Converted MNI_MCI240.nii to ./process_data\MCI\MNI_MCI240.png
# Converted MNI_MCI241.nii to ./process_data\MCI\MNI_MCI241.png
# Converted MNI_MCI242.nii to ./process_data\MCI\MNI_MCI242.png
# Converted MNI_MCI243.nii to ./process_data\MCI\MNI_MCI243.png
# Converted MNI_MCI244.nii to ./process_data\MCI\MNI_MCI244.png
# Converted MNI_MCI245.nii to ./process_data\MCI\MNI_MCI245.png
# Converted MNI_MCI246.nii to ./process_data\MCI\MNI_MCI246.png
# Converted MNI_MCI247.nii to ./process_data\MCI\MNI_MCI247.png
# Converted MNI_MCI248.nii to ./process_data\MCI\MNI_MCI248.png
# Converted MNI_MCI249.nii to ./process_data\MCI\MNI_MCI249.png
# Converted MNI_MCI250.nii to ./process_data\MCI\MNI_MCI250.png
# Conversion completed.
